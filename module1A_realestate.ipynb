# %%
import pandas as pd

# %%
df = pd.read_csv("boston-home-prices.csv")

# %%
df
# Out:
#     Size (sqft)  Bedrooms  Bathrooms  Location  Year Built  Condition  \
# 0          2500         4          3     Urban        1995  Excellent
# 1          1800         3          2  Suburban        2005       Good
# 2          3000         5          4     Rural        2010       Good
# 3          2000         3          2     Urban        1980       Fair
# 4          3500         5          3  Suburban        2015  Excellent
# 5          2800         4          2     Urban        2008  Excellent
# 6          2200         3          2     Rural        1990       Fair
# 7          4000         5          4     Urban        2020  Excellent
# 8          1500         2          1  Suburban        1975       Fair
# 9          2700         4          3     Rural        2003       Good
# 10         3200         5          3     Urban        2012  Excellent
# 11         1900         3          2  Suburban        1998       Good
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
X = df["Size (sqft)"].values.reshape(-1, 1) 
y = df["Sale Price"].values.reshape(-1, 1)
X
# Out:
# array([[2500],
#        [1800],
#        [3000],
#        [2000],
#        [3500],
#        [2800],
#        [2200],
#        [4000],
#        [1500],
#        [2700],
#        [3200],
#        [1900],
#        [2600],
#        [3700],
#        [2400],
#        [3300],
#        [2100],
#        [2800],
#        [3900],
#        [2300],
#        [3100],
#        [2000],
#        [3600],
#        [2500],
#        [4200],
#        [2700],
#        [3200],
#        [1800],
#        [3500],
#        [2400],
#        [2800],
#        [2300],
#        [4100],
#        [2600],
#        [3800],
#        [2900],
#        [3300],
#        [2200],
#        [3700],
#        [2500],
#        [4300],
#        [2600],
#        [3100],
#        [2400],
#        [3900],
#        [2800],
#        [3400],
#        [3000],
#        [3200],
#        [2000],
#        [3600],
#        [2500],
#        [4400],
#        [2800],
#        [3100],
#        [2300],
#        [4000]])

# %%
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg.predict([[2600]])
# Out:
# array([[498429.30788637]])
